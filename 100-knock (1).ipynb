# %%
# 問題00

str = "stressed"
reverse_str = str[::-1]
print(str +  " → " + reverse_str)
# Out:
# stressed → desserts

# %%
# 問題01

str = "パタトクカシー"
new_str = str[::2]
print(new_str)
# Out:
# パトカー

# %%
# 問題02

str1 = "パトカー"
str2 = "タクシー"
new_str = ""
for p, t in zip(str1, str2):
  new_str += p + t

print(new_str)
# Out:
# パタトクカシーー

# %%
# 問題03

sentence = "Now I need a drink, alcoholic of course, after the heavy lectures involving quantum mechanics."
words = sentence.replace(',', ' ').replace('.', ' ').split()

word_length_list = list()

for word in words:
  word_length_list.append(len(word))

print(word_length_list)
# Out:
# [3, 1, 4, 1, 5, 9, 2, 6, 5, 3, 5, 8, 9, 7, 9]

# %%
# 問題04

sentence = "Hi He Lied Because Boron Could Not Oxidize Fluorine. New Nations Might Also Sign Peace Security Clause. Arthur King Can."
words = sentence.split()
dict = {}

for i, word in enumerate(words, 1):
  if i in [1, 5, 6, 7, 8, 9, 15, 16, 19]:
    dict[i] = word[:1]
  else:
    dict[i] = word[:2]

print(dict)
# Out:
# {1: 'H', 2: 'He', 3: 'Li', 4: 'Be', 5: 'B', 6: 'C', 7: 'N', 8: 'O', 9: 'F', 10: 'Ne', 11: 'Na', 12: 'Mi', 13: 'Al', 14: 'Si', 15: 'P', 16: 'S', 17: 'Cl', 18: 'Ar', 19: 'K', 20: 'Ca'}

# %%
def n_gram(target, n):
  # 基準を1文字(単語)ずつ ずらしながらn文字分抜き出す
  return [ target[idx:idx + n] for idx in range(len(target)-1)]

target = "I am an NLPer"
print(n_gram(target, 2))


words = target.split(' ')
print(n_gram(words, 2))
# Out:
# ['I ', ' a', 'am', 'm ', ' a', 'an', 'n ', ' N', 'NL', 'LP', 'Pe', 'er']
# [['I', 'am'], ['am', 'an'], ['an', 'NLPer']]

# %%
# 問題06

def bi_gram(text):
    return {text[i:i+2] for i in range(len(text)-1)}

text_x = "paraparaparadise"
text_y = "paragraph"

X = bi_gram(text_x)
Y = bi_gram(text_y)

union_set = X | Y
intersection_set = X & Y
difference_set = X - Y

se_in_X = 'se' in X
se_in_Y = 'se' in Y

print(f"X: {X}")
print(f"Y: {Y}")
print(f"XとYの和集合: {union_set}")
print(f"XとYの積集合: {intersection_set}")
print(f"XとYの差集合(X - Y): {difference_set}")
print(f"’se’がXに含まれるか: {se_in_X}")
print(f"’se’がYに含まれるか: {se_in_Y}")
# Out:
# X: {'ad', 'ar', 'ap', 'pa', 'ra', 'is', 'di', 'se'}
# Y: {'gr', 'ar', 'ap', 'pa', 'ra', 'ag', 'ph'}
# XとYの和集合: {'ad', 'gr', 'ag', 'ar', 'ap', 'pa', 'ra', 'is', 'di', 'se', 'ph'}
# XとYの積集合: {'ar', 'ap', 'pa', 'ra'}
# XとYの差集合(X - Y): {'di', 'ad', 'is', 'se'}
# ’se’がXに含まれるか: True
# ’se’がYに含まれるか: False

# %%
# 問題07

def generate_sentence(time, words, temp):
  sentence = f"{time}時の{words}は{temp}"
  return sentence

x = 12
y = "気温"
z = 22.4
sentence = generate_sentence(x, y, z)
print(sentence)
# Out:
# 12時の気温は22.4

# %%
# 問題08

def cipher(text):
    result = ""
    for char in text:
        if char.islower():
            result += chr(219 - ord(char))
        else:
            result += char
    return result

# テストデータ
original_message = "Hello, World!"

# 暗号化
encryption_message = cipher(original_message)
print("暗号化されたメッセージ: " + encryption_message)

# 復号化
decryption_message = cipher(encryption_message)
print("復号化されたメッセージ: " + decryption_message)
# Out:
# 暗号化されたメッセージ: Hvool, Wliow!
# 復号化されたメッセージ: Hello, World!

# %%
# 問題09

import random

def random_word(word):
    if len(word) <= 4:
        return word
    else:
        middle_part = list(word[1:-1])
        random.shuffle(middle_part)
        return word[0] + ''.join(middle_part) + word[-1]

sentence = "I couldn’t believe that I could actually understand what I was reading : the phenomenal power of the human mind."
words = sentence.split()
random_words = [random_word(word) for word in words]
random_sentence = ' '.join(random_words)

print("並び替えた文:", random_sentence)
# Out:
# 並び替えた文: I colun’dt bveleie that I colud atlaucly unrdsneatd what I was ridneag : the pnonemheal peowr of the hmaun mind.
